# %% [markdown]
# # Install Rust
#
# This notebook will help you installing Rust.
# It covers *\*nix* like platforms, but focuses on macOS (at the moment).

# %%
## Install on macOS

Using homebrew:

# %%
brew install rust

# %% [markdown]
# ## Installing Other Tooling for this workshop
#
# Once we have `cargo` installed we can use it to install other tools for this workshop.
#
# If you want to follow along you will need Jupyter Notebooks and thre Rust kernel (for the installation part Bash kernel too).
#
# **Note**: The Bash kernel does not work out of the box on Windows and a lot of customization (and WSL or Git-Bash) is required and out of scope for now.
#
# - `evcxr_jupyter` is a module that will enable the notebooks to run interactive rust.

# %% [markdown]
# ## Requisite for running Jupyter Notebooks locally: Python

# %%
# Install Python on macOS

brew install python

# Install Jupyter Requirements

pip3 install -r jupyter_tools/requirements.txt

# %%
cargo install evcxr_jupyter
# Out:
#     Updating crates.io index
#   Downloaded evcxr_jupyter v0.12.0
#   Downloaded 1 crate (48.3 KB) in 3.41s
#   Installing evcxr_jupyter v0.12.0
#   Downloaded anymap v0.12.1
#   Downloaded always-assert v0.1.2
#   Downloaded arrayvec v0.7.2
#   Downloaded backtrace v0.3.65
#   Downloaded camino v1.0.7
#   Downloaded cargo_metadata v0.14.2
#   Downloaded dot v0.1.4
#   Downloaded form_urlencoded v1.0.1
#   Downloaded expect-test v1.2.2 bytes: 31.8 KB
#   Downloaded ena v0.14.0maining bytes: 23.1 KB
#   Downloaded instant v0.1.12
#   Downloaded hex v0.4.3
#   Downloaded getrandom v0.2.6
#   Downloaded dirs-sys v0.3.7
#   Downloaded smallvec v1.8.0ing bytes: 1.2 MB
#   Downloaded evcxr_input v1.0.0 bytes: 1.2 MB
#   Downloaded json v0.12.4aining bytes: 1.4 MB
#   Downloaded error-chain v0.10.0bytes: 5.3 MB
#   Downloaded matches v0.1.9ning bytes: 5.3 MB
#   Downloaded libloading v0.7.3g bytes: 5.2 MB
#   Downloaded hmac v0.11.0aining bytes: 5.2 MB
#   Downloaded syn v1.0.91maining bytes: 4.7 MB
#   Downloaded tempfile v3.3.0ing bytes: 4.6 MB
#   Downloaded tracing-core v0.1.26ytes: 4.3 MB
#   Downloaded version_check v0.9.4ytes: 4.3 MB
#   Downloaded which v4.2.5aining bytes: 4.1 MB
#   Downloaded walkdir v2.3.2ning bytes: 3.8 MB
#   Downloaded unicase v2.6.0ning bytes: 4.4 MB
#   Downloaded ra_ap_la-arena v0.0.76es: 4.3 MB
#   Downloaded ra_ap_limit v0.0.76bytes: 3.9 MB
#   Downloaded ra_ap_ide_assists v0.0.76 3.6 MB
#   Downloaded ra_ap_ide_ssr v0.0.76tes: 3.5 MB
#   Downloaded ra_ap_paths v0.0.76bytes: 3.3 MB
#   Downloaded zmq v0.9.2emaining bytes: 4.4 MB
#   Downloaded zmq-sys v0.11.0ing bytes: 4.2 MB
#   Downloaded remove_dir_all v0.5.3tes: 4.1 MB
#   Downloaded ra_ap_test_utils v0.0.76: 3.9 MB
#   Downloaded rayon-core v1.9.2g bytes: 3.7 MB
#   Downloaded serde_derive v1.0.136tes: 3.4 MB
#   Downloaded rustc-hash v1.1.0g bytes: 3.8 MB
#   Downloaded anyhow v1.0.56ning bytes: 3.9 MB
#   Downloaded subtle v2.4.1ining bytes: 3.7 MB
#   Downloaded tinyvec v1.5.1ning bytes: 3.5 MB
#   Downloaded text-size v1.1.0ng bytes: 3.4 MB
#   Downloaded smol_str v0.1.21ng bytes: 3.4 MB
#   Downloaded unicode-bidi v0.3.7bytes: 3.4 MB
#   Downloaded url v2.2.2emaining bytes: 3.4 MB
#   Downloaded uuid v0.8.2maining bytes: 3.2 MB
#   Downloaded sig v1.0.0emaining bytes: 3.0 MB
#   Downloaded ra_ap_syntax v0.0.76ytes: 3.0 MB
#   Downloaded ryu v1.0.9emaining bytes: 2.7 MB
#   Downloaded zeromq-src v0.1.10+4.3.2: 2.4 MB
#   Downloaded salsa v0.17.0-pre.1bytes: 2.0 MB
#   Downloaded itertools v0.10.3ng salsa ...
#   Downloaded quote v1.0.18ining bytes: 1.3 MB
#   Downloaded ra_ap_project_model v0.0.763 MB
#   Downloaded oorandom v11.1.3g bytes: 1.3 MB
#   Downloaded proc-macro2 v1.0.37ytes: 1.3 MB
#   Downloaded serde v1.0.136ing bytes: 1.2 MB
#   Downloaded serde_json v1.0.79bytes: 846.5 KB
#   Downloaded fst v0.4.7maining bytes: 522.4 KB
#   Downloaded rayon v1.5.2acting fst ...
#   Downloaded ra_ap_vfs-notify v0.0.76 393.3 KB
#   Downloaded libmimalloc-sys v0.1.24: 393.3 KB
#   Downloaded gimli v0.26.1cting libmimalloc-sys ...
#   Downloaded ra_ap_vfs v0.0.76g gimli ...
#   Downloaded semver v1.0.7
#   Downloaded ra_ap_tt v0.0.76
#   Downloaded ra_ap_stdx v0.0.76
#   Downloaded petgraph v0.5.1
#   Downloaded crossbeam-channel v0.5.4
#   Downloaded pkg-config v0.3.25
#   Downloaded once_cell v1.10.0
#   Downloaded crossbeam-deque v0.8.1
#   Downloaded num_cpus v1.13.1
#   Downloaded colored v2.0.0
#   Downloaded fixedbitset v0.2.0
#   Downloaded log v0.4.16
#   Downloaded itoa v1.0.1
#   Downloaded indexmap v1.8.1
#   Downloaded heck v0.3.3
#   Downloaded rustc-ap-rustc_lexer v725.0.0
#   Downloaded crossbeam-utils v0.8.8
#   Downloaded fastrand v1.7.0
#   Downloaded crossbeam-epoch v0.9.8
#   Downloaded libc v0.2.124
#   Downloaded unicode-normalization v0.1.19
#   Downloaded typenum v1.15.0
#   Downloaded tracing v0.1.34
#   Downloaded scoped-tls v1.0.0
#   Downloaded sha2 v0.9.9
#   Downloaded salsa-macros v0.17.0-pre.2
#   Downloaded regex-syntax v0.6.25
#   Downloaded addr2line v0.17.0
#   Downloaded bitflags v1.3.2
#   Downloaded rowan v0.14.1
#   Downloaded regex v1.5.5
#   Downloaded ra_ap_toolchain v0.0.76
#   Downloaded ra_ap_text_edit v0.0.76
#   Downloaded ra_ap_ide_diagnostics v0.0.76
#   Downloaded pulldown-cmark v0.8.0
#   Downloaded ra_ap_ide_completion v0.0.76
#   Downloaded ra_ap_hir_expand v0.0.76
#   Downloaded toml v0.2.1
#   Downloaded ra_ap_profile v0.0.76
#   Downloaded ra_ap_parser v0.0.76
#   Downloaded ra_ap_mbe v0.0.76
#   Downloaded ra_ap_ide_db v0.0.76
#   Downloaded lock_api v0.4.7
#   Downloaded ra_ap_hir_ty v0.0.76
#   Downloaded ra_ap_ide v0.0.76
#   Downloaded ra_ap_hir_def v0.0.76
#   Downloaded ra_ap_cfg v0.0.76
#   Downloaded pulldown-cmark-to-cmark v6.0.4
#   Downloaded ra_ap_base_db v0.0.76
#   Downloaded chalk-recursive v0.71.0
#   Downloaded metadeps v1.1.2
#   Downloaded fsevent-sys v4.1.0
#   Downloaded tracing-attributes v0.1.20
#   Downloaded ra_ap_hir v0.0.76
#   Downloaded object v0.28.3
#   Downloaded unicode-xid v0.2.2
#   Downloaded unicode-segmentation v1.9.0
#   Downloaded tinyvec_macros v0.1.0
#   Downloaded pin-project-lite v0.2.8
#   Downloaded parking_lot_core v0.8.5
#   Downloaded parking_lot v0.11.2
#   Downloaded miniz_oxide v0.5.1
#   Downloaded generic-array v0.14.5
#   Downloaded synstructure v0.12.6
#   Downloaded opaque-debug v0.3.0
#   Downloaded dirs v3.0.2
#   Downloaded notify v5.0.0-pre.13
#   Downloaded mimalloc v0.1.28
#   Downloaded jod-thread v0.1.2
#   Downloaded home v0.5.3
#   Downloaded cmake v0.1.48
#   Downloaded idna v0.2.3
#   Downloaded crypto-mac v0.11.1
#   Downloaded memoffset v0.6.5
#   Downloaded filetime v0.2.16
#   Downloaded cov-mark v2.0.0-pre.1
#   Downloaded chalk-derive v0.71.0
#   Downloaded evcxr v0.12.0
#   Downloaded drop_bomb v0.1.5
#   Downloaded dissimilar v1.0.3
#   Downloaded digest v0.9.0
#   Downloaded dashmap v4.0.2
#   Downloaded cpufeatures v0.2.2
#   Downloaded countme v2.0.4
#   Downloaded chalk-solve v0.71.0
#   Downloaded chalk-ir v0.71.0
#   Downloaded cargo-platform v0.1.2
#   Downloaded block-buffer v0.9.0
#   Downloaded 154 crates (11.7 MB) in 4.18s (largest was `fst` at 1.6 MB)
#    Compiling cfg-if v1.0.0
#    Compiling libc v0.2.124
#    Compiling autocfg v1.1.0
#    Compiling proc-macro2 v1.0.37
#    Compiling unicode-xid v0.2.2
#    Compiling syn v1.0.91
#    Compiling lazy_static v1.4.0
#    Compiling log v0.4.16
#    Compiling serde_derive v1.0.136
#    Compiling serde v1.0.136
#    Compiling rustc-hash v1.1.0
#    Compiling hashbrown v0.11.2
#    Compiling crossbeam-utils v0.8.8   ] 0/234: proc-macro2(build.rs), sy...
#    Compiling either v1.6.1            ] 1/234: proc-macro2(build.rs), sy...
#    Compiling once_cell v1.10.0        ] 2/234: proc-macro2(build.rs), sy...
#    Compiling scopeguard v1.1.0        ] 3/234: proc-macro2(build.rs), sy...
#    Compiling text-size v1.1.0         ] 4/234: proc-macro2(build.rs), sy...
#    Compiling ra_ap_la-arena v0.0.76   ] 5/234: proc-macro2(build.rs), sy...
#    Compiling smallvec v1.8.0          ] 6/234: proc-macro2(build.rs), sy...
#    Compiling pin-project-lite v0.2.8  ] 7/234: proc-macro2(build.rs), sy...
#    Compiling fst v0.4.7               ] 8/234: proc-macro2(build.rs), sy...
#    Compiling parking_lot_core v0.8.5  ] 9/234: proc-macro2(build.rs), sy...
#    Compiling bitflags v1.3.2         ] 10/234: proc-macro2(build.rs), sy...
#    Compiling unicode-segmentation v1.9.02/234: proc-macro2(build.rs), sy...
#    Compiling dissimilar v1.0.3       ] 13/234: proc-macro2(build.rs), sy...
#    Compiling drop_bomb v0.1.5        ] 14/234: proc-macro2(build.rs), sy...
#    Compiling cov-mark v2.0.0-pre.1   ] 15/234: proc-macro2(build.rs), sy...
#    Compiling ra_ap_paths v0.0.76     ] 16/234: proc-macro2(build.rs), sy...
#    Compiling version_check v0.9.4    ] 17/234: syn(build.rs), log(build....
#    Compiling cc v1.0.73
#    Compiling oorandom v11.1.3
#    Compiling fixedbitset v0.2.0
#    Compiling rayon-core v1.9.2
#    Compiling ra_ap_limit v0.0.76
#    Compiling anymap v0.12.1          ] 23/234: version_check, fixedbitse...
#    Compiling scoped-tls v1.0.0       ] 24/234: version_check, fixedbitse...
#    Compiling arrayvec v0.7.2         ] 25/234: version_check, fixedbitse...
#    Compiling memchr v2.4.1           ] 26/234: version_check, fixedbitse...
#    Compiling typenum v1.15.0         ] 27/234: version_check, fixedbitse...
#    Compiling pkg-config v0.3.25      ] 28/234: version_check, fixedbitse...
#    Compiling error-chain v0.10.0     ] 29/234: version_check, fixedbitse...
#    Compiling toml v0.2.1             ] 30/234: version_check, fixedbitse...
#    Compiling tinyvec_macros v0.1.0   ] 31/234: version_check, fixedbitse...
#    Compiling pulldown-cmark v0.8.0   ] 32/234: version_check, fixedbitse...
#    Compiling semver v1.0.7           ] 33/234: version_check, fixedbitse...
#    Compiling serde_json v1.0.79      ] 34/234: version_check, fixedbitse...
#    Compiling camino v1.0.7
#    Compiling matches v0.1.9          ] 36/234: version_check, fixedbitse...
#    Compiling itoa v1.0.1             ] 37/234: version_check, fixedbitse...
#    Compiling anyhow v1.0.56          ] 38/234: version_check, fixedbitse...
#    Compiling percent-encoding v2.1.0 ] 39/234: fixedbitset, semver(build...
#    Compiling unicode-bidi v0.3.7     ] 40/234: fixedbitset, semver(build...
#    Compiling ryu v1.0.9              ] 41/234: fixedbitset, semver(build...
#    Compiling same-file v1.0.6        ] 42/234: ryu, semver(build.rs), un...
#    Compiling adler v1.0.2            ] 43/234: ryu, semver(build.rs), un...
#    Compiling home v0.5.3
#    Compiling gimli v0.26.1           ] 45/234: ryu, home, adler, unicode...
#    Compiling rustc-demangle v0.1.21  ] 46/234: ryu, home, adler, unicode...
#    Compiling fastrand v1.7.0         ] 47/234: ryu, home, adler, unicode...
#    Compiling jod-thread v0.1.2
#    Compiling regex-syntax v0.6.25    ] 49/234: ryu, home, jod-thread, un...
#    Compiling zmq v0.9.2              ] 50/234: ryu, jod-thread, unicode-...
#    Compiling subtle v2.4.1           ] 51/234: ryu, zmq(build.rs), jod-t...
#    Compiling dot v0.1.4              ] 52/234: ryu, zmq(build.rs), jod-t...
#    Compiling remove_dir_all v0.5.3   ] 53/234: ryu, zmq(build.rs), subtl...
#    Compiling cpufeatures v0.2.2      ] 54/234: remove_dir_all, zmq(build...
#    Compiling opaque-debug v0.3.0     ] 55/234: remove_dir_all, zmq(build...
#    Compiling json v0.12.4            ] 57/234: unicode-segmentation, uni...
#    Compiling evcxr_input v1.0.0      ] 58/234: json, unicode-segmentatio...
#    Compiling hex v0.4.3              ] 59/234: json, unicode-segmentatio...
#    Compiling instant v0.1.12         ] 60/234: json, unicode-segmentatio...
#    Compiling libloading v0.7.3       ] 61/234: json, unicode-segmentatio...
#    Compiling tracing-core v0.1.26    ] 62/234: json, unicode-segmentatio...
#    Compiling itertools v0.10.3       ] 63/234: json, unicode-segmentatio...
#    Compiling ra_ap_text_edit v0.0.76 ] 64/234: json, unicode-segmentatio...
#    Compiling indexmap v1.8.1         ] 65/234: json, unicode-segmentatio...
#    Compiling memoffset v0.6.5        ] 66/234: json, unicode-segmentatio...
#    Compiling lock_api v0.4.7         ] 67/234: json, unicode-segmentatio...
#    Compiling crossbeam-epoch v0.9.8  ] 68/234: json, unicode-segmentatio...
#    Compiling rayon v1.5.2            ] 69/234: json, unicode-segmentatio...
#    Compiling num-traits v0.2.14      ] 70/234: json, unicode-bidi, memof...
#    Compiling num-integer v0.1.44
#    Compiling rustc-ap-rustc_lexer v725.0.0234: json, num-integer(build.r...
#    Compiling ra_ap_parser v0.0.76    ] 73/234: json, num-integer(build.r...
#    Compiling expect-test v1.2.2      ] 82/234: json, parking_lot_core(bu...
#    Compiling heck v0.3.3             ] 85/234: json, ra_ap_parser, fst(b...
#    Compiling tinyvec v1.5.1          ] 87/234: json, ra_ap_parser, fst(b...
#    Compiling generic-array v0.14.5   ] 88/234: json, tinyvec, ra_ap_pars...
#    Compiling unicase v2.6.0          ] 89/234: json, tinyvec, ra_ap_pars...
#    Compiling form_urlencoded v1.0.1  ] 91/234: json, tinyvec, ra_ap_pars...
#    Compiling cmake v0.1.48           ] 95/234: json, tinyvec, ra_ap_pars...
#    Compiling metadeps v1.1.2         ] 96/234: json, tinyvec, ra_ap_pars...
#    Compiling ra_ap_toolchain v0.0.76 ] 97/234: json, tinyvec, ra_ap_pars...
#    Compiling miniz_oxide v0.5.1      ] 98/234: json, tinyvec, ra_ap_pars...
#    Compiling walkdir v2.3.2          ] 99/234: json, tinyvec, ra_ap_pars...
#    Compiling backtrace v0.3.65      ] 102/234: json, tinyvec, ra_ap_pars...
#    Compiling libmimalloc-sys v0.1.24] 103/234: json, tinyvec, ra_ap_pars...
#    Compiling regex v1.5.5           ] 110/234: json, ra_ap_parser, index...
#    Compiling zeromq-src v0.1.10+4.3.2 120/234: generic-array(build), ra_...
#    Compiling addr2line v0.17.0      ] 125/234: typenum, backtrace(build)...
#    Compiling unicode-normalization v0.1.19234: typenum, ra_ap_parser, me...
#    Compiling always-assert v0.1.2   ] 131/234: typenum, num-traits, memc...
#    Compiling ena v0.14.0>           ] 132/234: num-traits, always-assert...
#    Compiling num_cpus v1.13.1       ] 133/234: num-traits, always-assert...
#    Compiling fsevent-sys v4.1.0     ] 135/234: num_cpus, num-traits, mem...
#    Compiling filetime v0.2.16       ] 136/234: fsevent-sys, num-traits, ...
#    Compiling dirs-sys v0.3.7        ] 137/234: fsevent-sys, num-traits, ...
#    Compiling time v0.1.44           ] 138/234: num-traits, filetime, mem...
#    Compiling atty v0.2.14           ] 139/234: num-traits, filetime, mem...
#    Compiling getrandom v0.2.6       ] 140/234: num-traits, filetime, mem...
#    Compiling which v4.2.5>          ] 141/234: num-traits, memchr, parki...
#    Compiling tempfile v3.3.0        ] 142/234: num-traits, memchr, parki...
#    Compiling sig v1.0.0==>          ] 143/234: tempfile, num-traits, mem...
#    Compiling quote v1.0.18          ] 144/234: tempfile, num-traits, sig...
#    Compiling crossbeam-channel v0.5.4 145/234: tempfile, num-traits, mem...
#    Compiling zmq-sys v0.11.0        ] 147/234: tempfile, num-traits, uni...
#    Compiling object v0.28.3         ] 148/234: tempfile, num-traits, uni...
#    Compiling ra_ap_stdx v0.0.76     ] 151/234: tempfile, num-traits, uni...
#    Compiling dashmap v4.0.2         ] 152/234: tempfile, num-traits, ra_...
#    Compiling parking_lot v0.11.2    ] 153/234: tempfile, num-traits, ra_...
#    Compiling dirs v3.0.2==>         ] 154/234: tempfile, ra_ap_stdx, obj...
#    Compiling idna v0.2.3==>         ] 155/234: tempfile, ra_ap_stdx, obj...
#    Compiling colored v2.0.0         ] 156/234: tempfile, ra_ap_stdx, obj...
#    Compiling ra_ap_vfs v0.0.76      ] 157/234: tempfile, colored, ra_ap_...
#    Compiling petgraph v0.5.1        ] 158/234: tempfile, colored, ra_ap_...
#    Compiling uuid v0.8.2==>         ] 159/234: petgraph, colored, ra_ap_...
#    Compiling crossbeam-deque v0.8.1 ] 164/234: petgraph, object, num-int...
#    Compiling notify v5.0.0-pre.13   ] 165/234: petgraph, object, num-int...
#    Compiling countme v2.0.4>        ] 166/234: petgraph, object, syn, re...
#    Compiling digest v0.9.0=>        ] 167/234: petgraph, object, countme...
#    Compiling block-buffer v0.9.0    ] 168/234: digest, object, countme, ...
#    Compiling crypto-mac v0.11.1     ] 169/234: object, countme, syn, blo...
#    Compiling url v2.2.2=====>       ] 170/234: object, countme, syn, cry...
#    Compiling chrono v0.4.19=>       ] 171/234: url, object, countme, syn...
#    Compiling pulldown-cmark-to-cmark v6.0.434: url, object, countme, syn...
#    Compiling ra_ap_profile v0.0.76  ] 174/234: rayon-core, url, object, ...
#    Compiling rowan v0.14.1==>       ] 175/234: rayon-core, url, object, ...
#    Compiling sha2 v0.9.9====>       ] 176/234: rayon-core, url, object, ...
#    Compiling hmac v0.11.0===>       ] 177/234: rayon-core, sha2, url, sy...
#    Compiling ra_ap_test_utils v0.0.76 180/234: rayon-core, sha2, rayon, ...
#    Compiling synstructure v0.12.6   ] 181/234: rayon-core, sha2, rayon, ...
#    Compiling mimalloc v0.1.28=>     ] 190/234: rayon, syn, libmimalloc-s...
#    Compiling tracing-attributes v0.1.2093/234: serde_derive, rayon, back...
#    Compiling salsa-macros v0.17.0-pre.293/234: serde_derive, rayon, trac...
#    Compiling chalk-derive v0.71.0   ] 193/234: serde_derive, rayon, trac...
#    Compiling chalk-ir v0.71.0=>     ] 195/234: serde_derive, chalk-deriv...
#    Compiling salsa v0.17.0-pre.1    ] 196/234: serde_derive, tracing-att...
#    Compiling tracing v0.1.34===>    ] 197/234: serde_derive, tracing-att...
#    Compiling ra_ap_vfs-notify v0.0.76 198/234: serde_derive, tracing, ch...
#    Compiling chalk-solve v0.71.0    ] 200/234: serde_derive, chalk-ir, r...
#    Compiling chalk-recursive v0.71.0] 203/234: chalk-solve, serde, zmq-s...
#    Compiling smol_str v0.1.21==>    ] 205/234: serde, zmq-sys(build)
#    Compiling cargo-platform v0.1.2
#    Compiling ra_ap_tt v0.0.76==>    ] 205/234: smol_str, semver, cargo-p...
#    Compiling ra_ap_syntax v0.0.76
#    Compiling ra_ap_cfg v0.0.76==>   ] 206/234: smol_str, semver, ra_ap_t...
#    Compiling cargo_metadata v0.14.2 ] 211/234: ra_ap_syntax, ra_ap_cfg, ...
#    Compiling ra_ap_base_db v0.0.76  ] 213/234: cargo_metadata, ra_ap_syn...
#    Compiling ra_ap_mbe v0.0.76
#    Compiling ra_ap_project_model v0.0.763/234: ra_ap_mbe, ra_ap_base_db,...
#    Compiling ra_ap_hir_expand v0.0.76 213/234: ra_ap_mbe, ra_ap_project_...
#    Compiling ra_ap_hir_def v0.0.76  ] 213/234: ra_ap_mbe, ra_ap_project_...
#    Compiling ra_ap_hir_ty v0.0.76   ] 214/234: ra_ap_mbe, ra_ap_project_...
#    Compiling ra_ap_hir v0.0.76===>  ] 221/234: ra_ap_project_model, ra_a...
#    Compiling ra_ap_ide_db v0.0.76>  ] 222/234: ra_ap_hir, ra_ap_project_...
#    Compiling ra_ap_ide_assists v0.0.76223/234: ra_ap_hir, ra_ap_ide_db, ...
#    Compiling ra_ap_ide_completion v0.0.76/234: ra_ap_hir, ra_ap_ide_db, ...
#    Compiling ra_ap_ide_ssr v0.0.76  ] 223/234: ra_ap_hir, ra_ap_ide_comp...
#    Compiling ra_ap_ide_diagnostics v0.0.76234: ra_ap_hir, ra_ap_ide_comp...
#    Compiling ra_ap_ide v0.0.76===>  ] 223/234: ra_ap_hir, ra_ap_ide_comp...
#    Compiling evcxr v0.12.0=======>  ] 224/234: ra_ap_ide_completion, ra_...
#    Compiling evcxr_jupyter v0.12.0> ] 232/234: ra_ap_ide
#     Finished release [optimized] target(s) in 7m 08s_jupyter(bin)
#   Installing /Users/guillem.riera/.cargo/bin/evcxr_jupyter
#    Installed package `evcxr_jupyter v0.12.0` (executable `evcxr_jupyter`)
# : 1

# %%
brew install cmake
# Out:
# Running `brew update --preinstall`...
# ==> Auto-updated Homebrew!
# Updated 4 taps (homebrew/cask-versions, homebrew/core, homebrew/cask and spring-io/tap).
# ==> New Formulae
# sophus
# ==> Updated Formulae
# Updated 64 formulae.
# ==> New Casks
# descript                                 manymc
# ==> Updated Casks
# Updated 40 casks.
#
# Warning: Treating cmake as a formula. For the cask, use homebrew/cask/cmake
# Warning: cmake 3.23.1 is already installed and up-to-date.
# To reinstall 3.23.1, run:
#   brew reinstall cmake
# : 1

# %%
### Configure the jupyter kernel for Rust

# %%
evcxr_jupyter --install
# Out:
# Writing /Users/guillem.riera/Library/Jupyter/kernels/rust/kernel.json
# Writing /Users/guillem.riera/Library/Jupyter/kernels/rust/logo-32x32.png
# Writing /Users/guillem.riera/Library/Jupyter/kernels/rust/logo-64x64.png
# Writing /Users/guillem.riera/Library/Jupyter/kernels/rust/logo-LICENSE.md
# Writing /Users/guillem.riera/Library/Jupyter/kernels/rust/kernel.js
# Writing /Users/guillem.riera/Library/Jupyter/kernels/rust/lint.js
# Writing /Users/guillem.riera/Library/Jupyter/kernels/rust/lint.css
# Writing /Users/guillem.riera/Library/Jupyter/kernels/rust/lint-LICENSE
# Writing /Users/guillem.riera/Library/Jupyter/kernels/rust/version.txt
# Installation complete
# : 1
